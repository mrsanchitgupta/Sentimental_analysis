# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from keras.models import model_from_json
from keras.models import load_model
import matplotlib.pyplot as plt

# Opening the files about data
X = pickle.load(open("X.pickle", "rb"))
y = pickle.load(open("y.pickle", "rb"))

# %%
X = X/255.0

# Building the model
model = Sequential()
# 3 convolutional layers
model.add(Conv2D(32, (3, 3), input_shape = X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 2 hidden layers
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

model.add(Dense(128))
model.add(Activation("relu"))

# The output layer with 13 neurons, for 13 classes
model.add(Dense(13))
model.add(Activation("softmax"))

# Compiling the model using some basic parameters
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# Training the model, with 40 iterations
# validation_split corresponds to the percentage of images used for the validation phase compared to all the images
history = model.fit(X, y, batch_size=32, epochs=40, validation_split=0.1)

# Saving the model
model_json = model.to_json()
with open("model.json", "w") as json_file :
    json_file.write(model_json)

model.save_weights("model.h5")
print("Saved model to disk")

model.save('CNN.model')

# Printing a graph showing the accuracy changes during the training phase
print(history.history.keys())
plt.figure(1)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
# Out:
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 68 samples, validate on 8 samples
# Epoch 1/40
# 68/68 [==============================] - 3s 39ms/sample - loss: 2.3775 - acc: 0.3971 - val_loss: 1.8093 - val_acc: 0.5000
# Epoch 2/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 1.3474 - acc: 0.6912 - val_loss: 2.1864 - val_acc: 0.5000
# Epoch 3/40
# 68/68 [==============================] - 0s 2ms/sample - loss: 1.1899 - acc: 0.6912 - val_loss: 0.8203 - val_acc: 0.5000
# Epoch 4/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6360 - acc: 0.6176 - val_loss: 0.6809 - val_acc: 0.6250
# Epoch 5/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6596 - acc: 0.7206 - val_loss: 0.9753 - val_acc: 0.5000
# Epoch 6/40
# 68/68 [==============================] - 0s 2ms/sample - loss: 0.6651 - acc: 0.6912 - val_loss: 0.6577 - val_acc: 0.6250
# Epoch 7/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6771 - acc: 0.5588 - val_loss: 0.6637 - val_acc: 0.7500
# Epoch 8/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6327 - acc: 0.7353 - val_loss: 1.0551 - val_acc: 0.5000
# Epoch 9/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.7206 - acc: 0.6912 - val_loss: 1.1084 - val_acc: 0.5000
# Epoch 10/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6937 - acc: 0.6912 - val_loss: 0.7809 - val_acc: 0.5000
# Epoch 11/40
# 68/68 [==============================] - 0s 2ms/sample - loss: 0.6497 - acc: 0.6912 - val_loss: 0.7122 - val_acc: 0.7500
# Epoch 12/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6834 - acc: 0.7941 - val_loss: 0.7002 - val_acc: 0.8750
# Epoch 13/40
# 68/68 [==============================] - 0s 2ms/sample - loss: 0.6674 - acc: 0.7206 - val_loss: 0.7198 - val_acc: 0.5000
# Epoch 14/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6069 - acc: 0.6912 - val_loss: 0.7989 - val_acc: 0.5000
# Epoch 15/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.5875 - acc: 0.7059 - val_loss: 0.6726 - val_acc: 0.5000
# Epoch 16/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.5994 - acc: 0.7500 - val_loss: 0.6222 - val_acc: 0.8750
# Epoch 17/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.5901 - acc: 0.7353 - val_loss: 0.6537 - val_acc: 0.6250
# Epoch 18/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.5412 - acc: 0.7500 - val_loss: 0.5783 - val_acc: 0.7500
# Epoch 19/40
# 68/68 [==============================] - 0s 2ms/sample - loss: 0.6197 - acc: 0.6912 - val_loss: 0.5923 - val_acc: 0.6250
# Epoch 20/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.5878 - acc: 0.6765 - val_loss: 1.1101 - val_acc: 0.5000
# Epoch 21/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6720 - acc: 0.6912 - val_loss: 0.8211 - val_acc: 0.5000
# Epoch 22/40
# 68/68 [==============================] - 0s 2ms/sample - loss: 0.5127 - acc: 0.7647 - val_loss: 0.5680 - val_acc: 0.7500
# Epoch 23/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.6084 - acc: 0.6324 - val_loss: 0.5559 - val_acc: 0.7500
# Epoch 24/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.5107 - acc: 0.8382 - val_loss: 0.8312 - val_acc: 0.5000
# Epoch 25/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.5483 - acc: 0.7059 - val_loss: 1.0115 - val_acc: 0.5000
# Epoch 26/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.5845 - acc: 0.7059 - val_loss: 0.7747 - val_acc: 0.5000
# Epoch 27/40
# 68/68 [==============================] - 0s 2ms/sample - loss: 0.4931 - acc: 0.7500 - val_loss: 0.6301 - val_acc: 0.6250
# Epoch 28/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.4835 - acc: 0.7647 - val_loss: 0.5623 - val_acc: 0.6250
# Epoch 29/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.4745 - acc: 0.7941 - val_loss: 0.5411 - val_acc: 0.6250
# Epoch 30/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.4347 - acc: 0.8088 - val_loss: 0.6361 - val_acc: 0.6250
# Epoch 31/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.4307 - acc: 0.8088 - val_loss: 0.7419 - val_acc: 0.6250
# Epoch 32/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.4654 - acc: 0.8235 - val_loss: 0.5324 - val_acc: 0.6250
# Epoch 33/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.3222 - acc: 0.8529 - val_loss: 0.4377 - val_acc: 0.8750
# Epoch 34/40
# 68/68 [==============================] - 0s 2ms/sample - loss: 0.3969 - acc: 0.8088 - val_loss: 1.0913 - val_acc: 0.6250
# Epoch 35/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.7748 - acc: 0.7206 - val_loss: 0.9225 - val_acc: 0.6250
# Epoch 36/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.3711 - acc: 0.8382 - val_loss: 0.3821 - val_acc: 0.8750
# Epoch 37/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.4760 - acc: 0.7500 - val_loss: 0.4261 - val_acc: 0.8750
# Epoch 38/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.4006 - acc: 0.8824 - val_loss: 0.5970 - val_acc: 0.6250
# Epoch 39/40
# 68/68 [==============================] - ETA: 0s - loss: 0.3996 - acc: 0.796 - 0s 3ms/sample - loss: 0.3942 - acc: 0.7941 - val_loss: 0.8442 - val_acc: 0.6250
# Epoch 40/40
# 68/68 [==============================] - 0s 3ms/sample - loss: 0.4217 - acc: 0.7500 - val_loss: 0.7521 - val_acc: 0.6250
# Saved model to disk
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])
